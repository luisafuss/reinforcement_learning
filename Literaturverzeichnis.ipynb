# %% [markdown]
# ## Literaturverzeichnis

# %% [markdown]
# **-> Eine Zelle pro Eintrag, dann kann man es einfacher alphabetisch sortieren**

# %% [markdown]
# Abbeel, Pieter; Klein, Dan: Markov Decision Processes. CS 188: Artificial Intelligence. University of California, Berkeley. Online verfügbar unter http://ai.berkeley.edu/slides/Lecture%208%20--%20MDPs%20I/SP14%20CS188%20Lecture%208%20--%20MDPs%20I.pptx, zuletzt geprüft am 27.05.2021.

# %% [markdown]
# Russell, Stuart J.; Norvig, Peter (2010): Artificial intelligence. A modern approach. 3. ed. Upper Saddle River, NJ: Prentice-Hall (Prentice-Hall series in artificial intelligence).
